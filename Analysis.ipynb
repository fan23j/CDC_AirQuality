# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import requests

pd.options.display.max_rows = 4000

# %%
data = pd.read_csv("year_2018.csv")
# Out:
# c:\users\fenge\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4,5,22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15119652 entries, 0 to 15119651
# Data columns (total 99 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   activity_year                             int64
#  1   lei                                       object
#  2   derived_msa-md                            int64
#  3   state_code                                object
#  4   county_code                               object
#  5   census_tract                              object
#  6   conforming_loan_limit                     object
#  7   derived_loan_product_type                 object
#  8   derived_dwelling_category                 object
#  9   derived_ethnicity                         object
#  10  derived_race                              object
#  11  derived_sex                               object
#  12  action_taken                              int64
# ...

# %%
df[["activity_year", "lei"]]
# Out:
#           activity_year                   lei
# 0                  2018  5493006VSECR4GWFB307
# 1                  2018  5493006VSECR4GWFB307
# 2                  2018  5493006VSECR4GWFB307
# 3                  2018  5493006VSECR4GWFB307
# 4                  2018  5493006VSECR4GWFB307
# ...                 ...                   ...
# 15119647           2018  5493006VSECR4GWFB307
# 15119648           2018  5493006VSECR4GWFB307
# 15119649           2018  5493006VSECR4GWFB307
# 15119650           2018  5493006VSECR4GWFB307
# 15119651           2018  5493006VSECR4GWFB307
#
# [15119652 rows x 2 columns]

# %%
df.hist(bins=50,figsize=(200, 200))
plt.show()

# %%
corr_matrix = df.corr()

# %%
corr_matrix["denial_reason-1"].sort_values(ascending=False)
# Out:
# denial_reason-1                             1.000000
# co-applicant_credit_score_type              0.853955
# applicant_credit_score_type                 0.853953
# submission_of_application                   0.842102
# initially_payable_to_institution            0.842091
# aus-1                                       0.841350
# reverse_mortgage                            0.838626
# business_or_commercial_purpose              0.838282
# open-end_line_of_credit                     0.836386
# manufactured_home_secured_property_type     0.835313
# manufactured_home_land_property_interest    0.834463
# interest_only_payment                       0.834462
# other_nonamortizing_features                0.834461
# negative_amortization                       0.834459
# balloon_payment                             0.834458
# co-applicant_ethnicity-5                    0.188410
# aus-2                                       0.126610
# occupancy_type                              0.097155
# ...

# %%
# "total_units"
# "debt_to_income_ratio"
# "_age"

correlationFields = [
    "loan_amount",
    "loan_to_value_ratio",
    "interest_rate",
    "rate_spread",
    "total_loan_costs",
#     "total_points_and_fees",
    "origination_charges",
#     "discount_points",
#     "lender_credits",
    "loan_term",
#     "prepayment_penalty_term",
#     "intro_rate_period",
    "property_value",
#     "multifamily_affordable_units",
    "income",
    "tract_population",
    "tract_minority_population_percent",
    "ffiec_msa_md_median_family_income",
    "tract_to_msa_income_percentage",
    "tract_owner_occupied_units",
    "tract_one_to_four_family_homes",
    "tract_median_age_of_housing_units",
]

# %%
dfCorrelation = df[correlationFields]

# %%
dfCorrelation2 = dfCorrelation.copy()

# %%
objects = [
    "loan_to_value_ratio",
    "interest_rate",
    "rate_spread",
    "total_loan_costs",
    "origination_charges",
    "loan_term",
    "property_value",
]

# %%
selector = (dfCorrelation2[objects[0]] != "Exempt") & (dfCorrelation2[objects[1]] != "Exempt") & (dfCorrelation2[objects[2]] != "Exempt") & (dfCorrelation2[objects[3]] != "Exempt") & (dfCorrelation2[objects[4]] != "Exempt") & (dfCorrelation2[objects[5]] != "Exempt") & (dfCorrelation2[objects[6]] != "Exempt")

# %%
dfCorrelation3 = dfCorrelation2[selector]

# %%
for field in objects:
    dfCorrelation3[field] = dfCorrelation3[field].astype(str).astype(float)
# Out:
# <ipython-input-25-54783f9dcb9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfCorrelation3[field] = dfCorrelation3[field].astype(str).astype(float)

# %%
dfCorrelation3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14720886 entries, 0 to 15119651
# Data columns (total 16 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   loan_amount                        float64
#  1   loan_to_value_ratio                float64
#  2   interest_rate                      float64
#  3   rate_spread                        float64
#  4   total_loan_costs                   float64
#  5   origination_charges                float64
#  6   loan_term                          float64
#  7   property_value                     float64
#  8   income                             float64
#  9   tract_population                   int64
#  10  tract_minority_population_percent  float64
#  11  ffiec_msa_md_median_family_income  int64
#  12  tract_to_msa_income_percentage     float64
#  13  tract_owner_occupied_units         int64
#  14  tract_one_to_four_family_homes     int64
# ...

# %%
corr_matrix3 = dfCorrelation3.corr()

# %%
corr_matrix3["loan_amount"].sort_values(ascending=False)
# Out:
# loan_amount                          1.000000
# property_value                       0.387481
# tract_to_msa_income_percentage       0.044775
# origination_charges                  0.034230
# ffiec_msa_md_median_family_income    0.034040
# total_loan_costs                     0.023869
# tract_minority_population_percent    0.010433
# income                               0.008663
# loan_to_value_ratio                  0.007820
# tract_median_age_of_housing_units    0.002926
# loan_term                           -0.000138
# interest_rate                       -0.000563
# tract_population                    -0.000693
# tract_owner_occupied_units          -0.008325
# tract_one_to_four_family_homes      -0.016005
# rate_spread                         -0.017835
# Name: loan_amount, dtype: float64

# %%
corr_matrix3
# Out:
#                                    loan_amount  loan_to_value_ratio  \
# loan_amount                           1.000000             0.007820
# loan_to_value_ratio                   0.007820             1.000000
# interest_rate                        -0.000563            -0.000004
# rate_spread                          -0.017835             0.000137
# total_loan_costs                      0.023869            -0.000051
# origination_charges                   0.034230            -0.000511
# loan_term                            -0.000138            -0.000478
# property_value                        0.387481             0.003297
# income                                0.008663            -0.000024
# tract_population                     -0.000693            -0.000291
# tract_minority_population_percent     0.010433            -0.000016
# ffiec_msa_md_median_family_income     0.034040             0.000042
# tract_to_msa_income_percentage        0.044775            -0.000560
# ...

# %%
dfCorrelation.head(20)
# Out:
#     loan_amount loan_to_value_ratio interest_rate rate_spread  \
# 0      105000.0                96.5           5.0        1.52
# 1      165000.0                97.0         4.875       0.695
# 2       95000.0                80.0           NaN         NaN
# 3      195000.0               100.0          4.25       -0.06
# 4      105000.0                97.0         4.875       0.435
# 5      135000.0               100.0           NaN         NaN
# 6      215000.0               100.0         4.625       0.319
# 7      135000.0                96.5         4.625       1.194
# 8      295000.0                95.0         4.375       0.893
# 9      185000.0               96.49           4.5       1.034
# 10     195000.0               87.73         4.375        0.57
# 11     225000.0                96.5          4.75       1.279
# 12     175000.0                96.5         4.625       1.166
# 13     155000.0                86.0           4.5       0.827
# ...

# %%
dfCorrelation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15119652 entries, 0 to 15119651
# Data columns (total 22 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   loan_amount                        float64
#  1   loan_to_value_ratio                object
#  2   interest_rate                      object
#  3   rate_spread                        object
#  4   total_loan_costs                   object
#  5   total_points_and_fees              object
#  6   origination_charges                object
#  7   discount_points                    object
#  8   lender_credits                     object
#  9   loan_term                          object
#  10  prepayment_penalty_term            object
#  11  intro_rate_period                  object
#  12  property_value                     object
#  13  multifamily_affordable_units       object
#  14  income                             float64
# ...
